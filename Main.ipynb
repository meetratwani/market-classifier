# %%
# !python3 -m venv venv

# %%
# !source venv/bin/activate

# %%
# !pip install -r requirements.txt

# %%
# 1. See all options
# !python3 main.py --list
# Out:
# ======================================================================
# AVAILABLE TICKER CATEGORIES
# ======================================================================
# ✓ SDG | SDG_CLEAN_ENERGY     | Clean Energy (SDG #7)
#       Tickers: ICLN, TAN, ENPH, FSLR
# ✓ SDG | SDG_HEALTH           | Healthcare (SDG #3)
#       Tickers: JNJ, PFE, UNH, ABBV
#   --- | TECH                 | Technology
#       Tickers: AAPL, MSFT, GOOGL, NVDA
#   --- | FINANCE              | Financial Services
#       Tickers: JPM, BAC, GS, MS
#   --- | CONSUMER             | Consumer & Retail
#       Tickers: AMZN, WMT, HD, NKE
#   --- | ENERGY_TRADITIONAL   | Traditional Energy
#       Tickers: XOM, CVX, COP, SLB
# ======================================================================

# %%
# 2. Run clean energy (SDG)
# !python3 main.py --category SDG_CLEAN_ENERGY
# Out:
# ======================================================================
# MULTI-CATEGORY MARKET MOVEMENT CLASSIFIER
# ======================================================================
#
# [1/6] Loading Data...
# Initialized: Clean Energy (SDG #7)
# Tickers: ['ICLN', 'TAN', 'ENPH', 'FSLR']
# SDG Aligned: Yes
#
# Downloading 2y of data for SDG_CLEAN_ENERGY...
# ✓ Successfully downloaded 502 days of data
#
# [2/6] Engineering Features...
#   Processing ICLN...
#   Processing TAN...
#   Processing ENPH...
#   Processing FSLR...
#   Creating target labels using ICLN...
#   Mode: Predicting ANY move (UP/DOWN)
#   ✓ Saved: 468 samples, 145 features
#
# [3/6] Training XGBoost Model...
#   Training set: 374 samples
#   Test set: 94 samples
# Training XGBoost model...
# Training complete!
#
# [4/6] Evaluating Model...
#
# ======================================================================
# MODEL PERFORMANCE - Clean Energy (SDG #7)
# ======================================================================
# Training Accuracy:   1.0000
# Test Accuracy:       0.6277
# Test F1-Score:       0.6392
# Test ROC-AUC:        0.6557
#
# Confusion Matrix:
# [[28 14]
#  [21 31]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62        42
#            1       0.69      0.60      0.64        52
#
#     accuracy                           0.63        94
#    macro avg       0.63      0.63      0.63        94
# weighted avg       0.64      0.63      0.63        94
#
#
# [5/6] Generating Visualizations...
# Confusion matrix saved to results/sdg_clean_energy_confusion_matrix.png
# ROC curve saved to results/sdg_clean_energy_roc_curve.png
# Feature importance plot saved to results/sdg_clean_energy_feature_importance.png
#
# Top 10 Most Important Features:
#            feature  importance
#            TAN_Low    0.033295
#   ENPH_close_lag_1    0.025484
#   ICLN_macd_signal    0.018441
#        ICLN_sma_20    0.018179
#         TAN_bb_low    0.018130
#        FSLR_rsi_14    0.017392
#         ICLN_Close    0.016312
#   ICLN_bb_position    0.015297
#    TAN_bb_position    0.013715
# ICLN_volume_sma_20    0.011925
#
# [6/6] Making Next-Day Prediction...
#
# ======================================================================
# NEXT DAY PREDICTION - ICLN
# ======================================================================
# Predicted Movement:  DOWN
# Confidence:          76.89%
# P(DOWN):             76.89%
# P(UP):               23.11%
# Model saved to models/sdg_clean_energy_xgboost_model.json
#
# ======================================================================
# PIPELINE COMPLETE!
# ======================================================================
# ✓ Data saved to: data/sdg_clean_energy_data.csv
# ✓ Model saved to: models/sdg_clean_energy_xgboost_model.json
# ✓ Metrics saved to: results/sdg_clean_energy_metrics.txt
# ✓ Visualizations in: results/

# %%
# 3. Compare all categories
# !python3 main.py --multi
# Out:
# ======================================================================
# RUNNING MULTI-CATEGORY ANALYSIS
# ======================================================================
#
#
# ======================================================================
# CATEGORY: SDG_CLEAN_ENERGY
# ======================================================================
#
# ======================================================================
# MULTI-CATEGORY MARKET MOVEMENT CLASSIFIER
# ======================================================================
#
# [1/6] Loading Data...
# Initialized: Clean Energy (SDG #7)
# Tickers: ['ICLN', 'TAN', 'ENPH', 'FSLR']
# SDG Aligned: Yes
#
# Downloading 2y of data for SDG_CLEAN_ENERGY...
# ✓ Successfully downloaded 502 days of data
#
# [2/6] Engineering Features...
#   Processing ICLN...
#   Processing TAN...
#   Processing ENPH...
#   Processing FSLR...
#   Creating target labels using ICLN...
#   Mode: Predicting ANY move (UP/DOWN)
#   ✓ Saved: 468 samples, 145 features
#
# [3/6] Training XGBoost Model...
#   Training set: 374 samples
#   Test set: 94 samples
# Training XGBoost model...
# Training complete!
#
# [4/6] Evaluating Model...
#
# ======================================================================
# MODEL PERFORMANCE - Clean Energy (SDG #7)
# ======================================================================
# Training Accuracy:   1.0000
# Test Accuracy:       0.6277
# Test F1-Score:       0.6392
# Test ROC-AUC:        0.6557
#
# Confusion Matrix:
# [[28 14]
#  [21 31]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.67      0.62        42
#            1       0.69      0.60      0.64        52
#
#     accuracy                           0.63        94
#    macro avg       0.63      0.63      0.63        94
# weighted avg       0.64      0.63      0.63        94
#
#
# [5/6] Generating Visualizations...
# Confusion matrix saved to results/sdg_clean_energy_confusion_matrix.png
# ROC curve saved to results/sdg_clean_energy_roc_curve.png
# Feature importance plot saved to results/sdg_clean_energy_feature_importance.png
#
# Top 10 Most Important Features:
#            feature  importance
#            TAN_Low    0.033308
#   ENPH_close_lag_1    0.025494
#   ICLN_macd_signal    0.018448
#        ICLN_sma_20    0.018186
#         TAN_bb_low    0.018137
#        FSLR_rsi_14    0.017399
#         ICLN_Close    0.016318
#   ICLN_bb_position    0.015303
#    TAN_bb_position    0.013720
# ICLN_volume_sma_20    0.011929
#
# [6/6] Making Next-Day Prediction...
#
# ======================================================================
# NEXT DAY PREDICTION - ICLN
# ======================================================================
# Predicted Movement:  DOWN
# Confidence:          76.89%
# P(DOWN):             76.89%
# P(UP):               23.11%
# Model saved to models/sdg_clean_energy_xgboost_model.json
#
# ======================================================================
# PIPELINE COMPLETE!
# ======================================================================
# ✓ Data saved to: data/sdg_clean_energy_data.csv
# ✓ Model saved to: models/sdg_clean_energy_xgboost_model.json
# ✓ Metrics saved to: results/sdg_clean_energy_metrics.txt
# ✓ Visualizations in: results/
#
#
# ======================================================================
# CATEGORY: SDG_HEALTH
# ======================================================================
#
# ======================================================================
# MULTI-CATEGORY MARKET MOVEMENT CLASSIFIER
# ======================================================================
#
# [1/6] Loading Data...
# Initialized: Healthcare (SDG #3)
# Tickers: ['JNJ', 'PFE', 'UNH', 'ABBV']
# SDG Aligned: Yes
#
# Downloading 2y of data for SDG_HEALTH...
# ✓ Successfully downloaded 502 days of data
#
# [2/6] Engineering Features...
#   Processing JNJ...
#   Processing PFE...
#   Processing UNH...
#   Processing ABBV...
#   Creating target labels using JNJ...
#   Mode: Predicting ANY move (UP/DOWN)
#   ✓ Saved: 468 samples, 145 features
#
# [3/6] Training XGBoost Model...
#   Training set: 374 samples
#   Test set: 94 samples
# Training XGBoost model...
# Training complete!
#
# [4/6] Evaluating Model...
#
# ======================================================================
# MODEL PERFORMANCE - Healthcare (SDG #3)
# ======================================================================
# Training Accuracy:   1.0000
# Test Accuracy:       0.4574
# Test F1-Score:       0.4950
# Test ROC-AUC:        0.4948
#
# Confusion Matrix:
# [[18 20]
#  [31 25]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.37      0.47      0.41        38
#            1       0.56      0.45      0.50        56
#
#     accuracy                           0.46        94
#    macro avg       0.46      0.46      0.45        94
# weighted avg       0.48      0.46      0.46        94
#
#
# [5/6] Generating Visualizations...
# Confusion matrix saved to results/sdg_health_confusion_matrix.png
# ROC curve saved to results/sdg_health_roc_curve.png
# Feature importance plot saved to results/sdg_health_feature_importance.png
#
# Top 10 Most Important Features:
#              feature  importance
#           PFE_bb_mid    0.029148
# ABBV_rolling_max_14d    0.018994
#        JNJ_macd_diff    0.016027
#           UNH_sma_20    0.014999
#  JNJ_price_to_sma_10    0.013871
#           JNJ_sma_10    0.013622
#   PFE_price_to_sma_5    0.013589
#    PFE_volume_sma_20    0.013484
#            UNH_sma_5    0.012920
#  JNJ_rolling_min_14d    0.012679
#
# [6/6] Making Next-Day Prediction...
#
# ======================================================================
# NEXT DAY PREDICTION - JNJ
# ======================================================================
# Predicted Movement:  DOWN
# Confidence:          76.39%
# P(DOWN):             76.39%
# P(UP):               23.61%
# Model saved to models/sdg_health_xgboost_model.json
#
# ======================================================================
# PIPELINE COMPLETE!
# ======================================================================
# ✓ Data saved to: data/sdg_health_data.csv
# ✓ Model saved to: models/sdg_health_xgboost_model.json
# ✓ Metrics saved to: results/sdg_health_metrics.txt
# ✓ Visualizations in: results/
#
#
# ======================================================================
# CATEGORY: TECH
# ======================================================================
#
# ======================================================================
# MULTI-CATEGORY MARKET MOVEMENT CLASSIFIER
# ======================================================================
#
# [1/6] Loading Data...
# Initialized: Technology
# Tickers: ['AAPL', 'MSFT', 'GOOGL', 'NVDA']
# SDG Aligned: No
#
# Downloading 2y of data for TECH...
# ✓ Successfully downloaded 502 days of data
#
# [2/6] Engineering Features...
#   Processing AAPL...
#   Processing MSFT...
#   Processing GOOGL...
#   Processing NVDA...
#   Creating target labels using AAPL...
#   Mode: Predicting ANY move (UP/DOWN)
#   ✓ Saved: 468 samples, 145 features
#
# [3/6] Training XGBoost Model...
#   Training set: 374 samples
#   Test set: 94 samples
# Training XGBoost model...
# Training complete!
#
# [4/6] Evaluating Model...
#
# ======================================================================
# MODEL PERFORMANCE - Technology
# ======================================================================
# Training Accuracy:   1.0000
# Test Accuracy:       0.5426
# Test F1-Score:       0.6261
# Test ROC-AUC:        0.5473
#
# Confusion Matrix:
# [[15 29]
#  [14 36]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.52      0.34      0.41        44
#            1       0.55      0.72      0.63        50
#
#     accuracy                           0.54        94
#    macro avg       0.54      0.53      0.52        94
# weighted avg       0.54      0.54      0.53        94
#
#
# [5/6] Generating Visualizations...
# Confusion matrix saved to results/tech_confusion_matrix.png
# ROC curve saved to results/tech_roc_curve.png
# Feature importance plot saved to results/tech_feature_importance.png
#
# Top 10 Most Important Features:
#              feature  importance
#    GOOGL_bb_position    0.021573
#     MSFT_close_lag_2    0.018601
#     NVDA_close_lag_2    0.016041
#          GOOGL_sma_5    0.014999
#          NVDA_sma_20    0.014865
#          AAPL_rsi_14    0.013941
#         GOOGL_sma_20    0.013694
#          GOOGL_Close    0.013417
#     MSFT_close_lag_1    0.013338
# NVDA_price_to_sma_20    0.013031
#
# [6/6] Making Next-Day Prediction...
#
# ======================================================================
# NEXT DAY PREDICTION - AAPL
# ======================================================================
# Predicted Movement:  UP
# Confidence:          76.35%
# P(DOWN):             23.65%
# P(UP):               76.35%
# Model saved to models/tech_xgboost_model.json
#
# ======================================================================
# PIPELINE COMPLETE!
# ======================================================================
# ✓ Data saved to: data/tech_data.csv
# ✓ Model saved to: models/tech_xgboost_model.json
# ✓ Metrics saved to: results/tech_metrics.txt
# ✓ Visualizations in: results/
#
#
# ======================================================================
# CATEGORY: FINANCE
# ======================================================================
#
# ======================================================================
# MULTI-CATEGORY MARKET MOVEMENT CLASSIFIER
# ======================================================================
#
# [1/6] Loading Data...
# Initialized: Financial Services
# Tickers: ['JPM', 'BAC', 'GS', 'MS']
# SDG Aligned: No
#
# Downloading 2y of data for FINANCE...
# ✓ Successfully downloaded 502 days of data
#
# [2/6] Engineering Features...
#   Processing JPM...
#   Processing BAC...
#   Processing GS...
#   Processing MS...
#   Creating target labels using JPM...
#   Mode: Predicting ANY move (UP/DOWN)
#   ✓ Saved: 468 samples, 145 features
#
# [3/6] Training XGBoost Model...
#   Training set: 374 samples
#   Test set: 94 samples
# Training XGBoost model...
# Training complete!
#
# [4/6] Evaluating Model...
#
# ======================================================================
# MODEL PERFORMANCE - Financial Services
# ======================================================================
# Training Accuracy:   1.0000
# Test Accuracy:       0.4787
# Test F1-Score:       0.4948
# Test ROC-AUC:        0.5298
#
# Confusion Matrix:
# [[21 21]
#  [28 24]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46        42
#            1       0.53      0.46      0.49        52
#
#     accuracy                           0.48        94
#    macro avg       0.48      0.48      0.48        94
# weighted avg       0.49      0.48      0.48        94
#
#
# [5/6] Generating Visualizations...
# Confusion matrix saved to results/finance_confusion_matrix.png
# ROC curve saved to results/finance_roc_curve.png
# Feature importance plot saved to results/finance_feature_importance.png
#
# Top 10 Most Important Features:
#             feature  importance
#  MS_rolling_min_14d    0.021348
#          MS_bb_high    0.016022
# BAC_rolling_min_14d    0.015604
#         BAC_bb_high    0.015408
#     JPM_close_lag_3    0.014673
#       JPM_macd_diff    0.013940
#      MS_macd_signal    0.012662
#           GS_sma_20    0.012413
#             MS_High    0.012317
# BAC_price_range_14d    0.012131
#
# [6/6] Making Next-Day Prediction...
#
# ======================================================================
# NEXT DAY PREDICTION - JPM
# ======================================================================
# Predicted Movement:  DOWN
# Confidence:          60.59%
# P(DOWN):             60.59%
# P(UP):               39.41%
# Model saved to models/finance_xgboost_model.json
#
# ======================================================================
# PIPELINE COMPLETE!
# ======================================================================
# ✓ Data saved to: data/finance_data.csv
# ✓ Model saved to: models/finance_xgboost_model.json
# ✓ Metrics saved to: results/finance_metrics.txt
# ✓ Visualizations in: results/
#
#
# ======================================================================
# CATEGORY: CONSUMER
# ======================================================================
#
# ======================================================================
# MULTI-CATEGORY MARKET MOVEMENT CLASSIFIER
# ======================================================================
#
# [1/6] Loading Data...
# Initialized: Consumer & Retail
# Tickers: ['AMZN', 'WMT', 'HD', 'NKE']
# SDG Aligned: No
#
# Downloading 2y of data for CONSUMER...
# ✓ Successfully downloaded 502 days of data
#
# [2/6] Engineering Features...
#   Processing AMZN...
#   Processing WMT...
#   Processing HD...
#   Processing NKE...
#   Creating target labels using AMZN...
#   Mode: Predicting ANY move (UP/DOWN)
#   ✓ Saved: 468 samples, 145 features
#
# [3/6] Training XGBoost Model...
#   Training set: 374 samples
#   Test set: 94 samples
# Training XGBoost model...
# Training complete!
#
# [4/6] Evaluating Model...
#
# ======================================================================
# MODEL PERFORMANCE - Consumer & Retail
# ======================================================================
# Training Accuracy:   1.0000
# Test Accuracy:       0.5426
# Test F1-Score:       0.4557
# Test ROC-AUC:        0.5678
#
# Confusion Matrix:
# [[33  9]
#  [34 18]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.79      0.61        42
#            1       0.67      0.35      0.46        52
#
#     accuracy                           0.54        94
#    macro avg       0.58      0.57      0.53        94
# weighted avg       0.59      0.54      0.52        94
#
#
# [5/6] Generating Visualizations...
# Confusion matrix saved to results/consumer_confusion_matrix.png
# ROC curve saved to results/consumer_roc_curve.png
# Feature importance plot saved to results/consumer_feature_importance.png
#
# Top 10 Most Important Features:
#              feature  importance
#  WMT_price_to_sma_10    0.016311
#      WMT_close_lag_1    0.016262
#           WMT_sma_20    0.015108
# AMZN_rolling_min_14d    0.014803
#           NKE_sma_10    0.014506
#              NKE_Low    0.013738
#           WMT_roc_10    0.013536
#      NKE_close_lag_2    0.012929
#            HD_bb_low    0.012797
#       AMZN_return_5d    0.011902
#
# [6/6] Making Next-Day Prediction...
#
# ======================================================================
# NEXT DAY PREDICTION - AMZN
# ======================================================================
# Predicted Movement:  DOWN
# Confidence:          78.72%
# P(DOWN):             78.72%
# P(UP):               21.28%
# Model saved to models/consumer_xgboost_model.json
#
# ======================================================================
# PIPELINE COMPLETE!
# ======================================================================
# ✓ Data saved to: data/consumer_data.csv
# ✓ Model saved to: models/consumer_xgboost_model.json
# ✓ Metrics saved to: results/consumer_metrics.txt
# ✓ Visualizations in: results/
#
#
# ======================================================================
# CATEGORY COMPARISON SUMMARY
# ======================================================================
# Category                  Test Acc     ROC-AUC             SDG
# ----------------------------------------------------------------------
# SDG_CLEAN_ENERGY              62.77%       0.656       ✓ Yes
# SDG_HEALTH                    45.74%       0.495       ✓ Yes
# TECH                          54.26%       0.547          No
# FINANCE                       47.87%       0.530          No
# CONSUMER                      54.26%       0.568          No
# ======================================================================

# %%
# 4. Custom stocks
python3 main.py --custom TSLA PLTR SNOW
